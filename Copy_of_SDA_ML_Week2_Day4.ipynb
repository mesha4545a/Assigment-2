# %% [markdown]
# <a href="https://colab.research.google.com/github/mesha4545a/Assigment-2/blob/master/Copy_of_SDA_ML_Week2_Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import accuracy_score
# Import what you feel is neccessary from scikit-learn

# %% [markdown]
# <center><H1>Adult Dataset Classification</H1></center>
#
#
# <p align="center">
#   <img width="700" height="350" src="https://media.giphy.com/media/HoffxyN8ghVuw/giphy.gif">
# </p>
#
# ### Target = "<=50k"
#
# ### [Data Dictionary/Details](https://archive.ics.uci.edu/ml/datasets/Adult)
#
# - age: continuous.
# - workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - fnlwgt: continuous.
# - education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - education-num: continuous.
# - marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - sex: Female, Male.
# - capital-gain: continuous.
# - capital-loss: continuous.
# - hours-per-week: continuous.
# - native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# - "<=50k" = >50K, <=50K (TARGET)
#
# <center><H3>-----RULES-----</H3></center>
#
# <p align="center">
#   <img width="700" height="350" src="https://media.giphy.com/media/iB4PoTVka0Xnul7UaC/giphy.gif">
# </p>
#
# ### Your data has already been split into training and testing sets, do not use `train_test_split`
# ### Only use your training set for EDA, Cleaning, Modeling, etc.
# - **You will have to perform the same transformations on your test set that you apply to your training set. The column names are exactly the same as your training set.**
#
# ### **DO NOT** look into your test set until you are ready to test the accuracy of your model. Your test set is supposed to represent unseen data and lets treat it that way until we are ready to test our accuracy. Your transformations on your training set should work on your test set since it has the exact same column names and the values are exactly the same.

# %%
# Starter Code --DO NOT ADJUST--
col_names = ["age", "workclass", "fnlwgt", "education", "education_num", "marital_status", "ooccupation", "relationship", "race", "sex", "capital_gain", "capital_loss", "hours_per_week", "native_country", "target"]
training = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", names=col_names).drop("race", axis=1)
test = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test", names=col_names, skiprows=1).drop("race", axis=1)

# Create Train
X_train = training.drop("target", axis=1)
y_train = training["target"].map({" <=50K" : "<=50K"  , ' >50K':'>50K'})
# y_train = y_train.map({'<=50K': 0, '>50K': 1})


# Create Test
X_test = test.drop("target", axis=1)
y_test = test["target"].map({" <=50K." : "<=50K"  , ' >50K.':'>50K'})
# y_test = y_test.map({'<=50K': 0, '>50K': 1})

# %% [markdown]
# ### **Determine your baseline model accuracy**

# %%
def baseline_model(n_predictions, value_to_predict):
    """
    just predict a single value (e.g. mean) for everything
    """
    baseline_preds = []
    for i in range(n_predictions):
        baseline_preds.append(value_to_predict)
    return pd.Series(baseline_preds)

# %%
n_predictions = len(y_test)  # how many predictions to make?
baseline_value = y_train.value_counts().index[0] # what value to predict? (classification = most common class)

baseline_model(n_predictions, baseline_value)
# Out:
# 0        <=50K
# 1        <=50K
# 2        <=50K
# 3        <=50K
# 4        <=50K
#          ...
# 16276    <=50K
# 16277    <=50K
# 16278    <=50K
# 16279    <=50K
# 16280    <=50K
# Length: 16281, dtype: object

# %%
# score baseline model...
#https://stackoverflow.com/questions/46406720/labelencoder-typeerror-not-supported-between-instances-of-float-and-str
accuracy_score(y_test.astype(str), baseline_preds)
# Out:
# 0.7637737239727289

# %% [markdown]
# ### **Visualize the data in your training set (EDA)**
# - Please only create 3 visualization explaining different insights in the data. So you have enough time to model.
# - You can only use one of each plot type, this means you cant make 3 bar plot, 3 Scatter Plots, etc.

# %%
corr = training.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_157659d0_662e_11eb_acb1_0242ac1c0002row0_col0,#T_157659d0_662e_11eb_acb1_0242ac1c0002row1_col1,#T_157659d0_662e_11eb_acb1_0242ac1c0002row2_col2,#T_157659d0_662e_11eb_acb1_0242ac1c0002row3_col3,#T_157659d0_662e_11eb_acb1_0242ac1c0002row4_col4,#T_157659d0_662e_11eb_acb1_0242ac1c0002row5_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row0_col1,#T_157659d0_662e_11eb_acb1_0242ac1c0002row1_col0,#T_157659d0_662e_11eb_acb1_0242ac1c0002row1_col2,#T_157659d0_662e_11eb_acb1_0242ac1c0002row1_col5,#T_157659d0_662e_11eb_acb1_0242ac1c0002row3_col4,#T_157659d0_662e_11eb_acb1_0242ac1c0002row4_col3{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row0_col2{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row0_col3,#T_157659d0_662e_11eb_acb1_0242ac1c0002row2_col4,#T_157659d0_662e_11eb_acb1_0242ac1c0002row5_col3{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row0_col4{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row0_col5,#T_157659d0_662e_11eb_acb1_0242ac1c0002row5_col4{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row1_col3,#T_157659d0_662e_11eb_acb1_0242ac1c0002row2_col1{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row1_col4{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row2_col0{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row2_col3{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row2_col5{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row3_col0{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row3_col1,#T_157659d0_662e_11eb_acb1_0242ac1c0002row4_col5{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row3_col2{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row3_col5{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row4_col0{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row4_col1{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row4_col2{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row5_col0{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row5_col1{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_157659d0_662e_11eb_acb1_0242ac1c0002row5_col2{
#             background-color:  #7597f6;
#             color:  #000000;
#         }</style><table id="T_157659d0_662e_11eb_acb1_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >age</th>        <th class="col_heading level0 col1" >fnlwgt</th>        <th class="col_heading level0 col2" >education_num</th>        <th class="col_heading level0 col3" >capital_gain</th>        <th class="col_heading level0 col4" >capital_loss</th>        <th class="col_heading level0 col5" >hours_per_week</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_157659d0_662e_11eb_acb1_0242ac1c0002level0_row0" class="row_heading level0 row0" >age</th>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row0_col1" class="data row0 col1" >-0.076646</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row0_col2" class="data row0 col2" >0.036527</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row0_col3" class="data row0 col3" >0.077674</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row0_col4" class="data row0 col4" >0.057775</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row0_col5" class="data row0 col5" >0.068756</td>
#             </tr>
#             <tr>
#                         <th id="T_157659d0_662e_11eb_acb1_0242ac1c0002level0_row1" class="row_heading level0 row1" >fnlwgt</th>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row1_col0" class="data row1 col0" >-0.076646</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row1_col2" class="data row1 col2" >-0.043195</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row1_col3" class="data row1 col3" >0.000432</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row1_col4" class="data row1 col4" >-0.010252</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row1_col5" class="data row1 col5" >-0.018768</td>
#             </tr>
#             <tr>
#                         <th id="T_157659d0_662e_11eb_acb1_0242ac1c0002level0_row2" class="row_heading level0 row2" >education_num</th>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row2_col0" class="data row2 col0" >0.036527</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row2_col1" class="data row2 col1" >-0.043195</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row2_col3" class="data row2 col3" >0.122630</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row2_col4" class="data row2 col4" >0.079923</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row2_col5" class="data row2 col5" >0.148123</td>
#             </tr>
#             <tr>
#                         <th id="T_157659d0_662e_11eb_acb1_0242ac1c0002level0_row3" class="row_heading level0 row3" >capital_gain</th>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row3_col0" class="data row3 col0" >0.077674</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row3_col1" class="data row3 col1" >0.000432</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row3_col2" class="data row3 col2" >0.122630</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row3_col4" class="data row3 col4" >-0.031615</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row3_col5" class="data row3 col5" >0.078409</td>
#             </tr>
#             <tr>
#                         <th id="T_157659d0_662e_11eb_acb1_0242ac1c0002level0_row4" class="row_heading level0 row4" >capital_loss</th>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row4_col0" class="data row4 col0" >0.057775</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row4_col1" class="data row4 col1" >-0.010252</td>
#                         <td id="T_157659d0_662e_11eb_acb1_0242ac1c0002row4_col2" class="data row4 col2" >0.079923</td>

# %%
import seaborn as sns
sns.pairplot(training, hue='target');

# %%
import matplotlib.pyplot as plt

training['target'].value_counts().plot.pie(explode=[0.04650, 0.01688], autopct='%1.1f%%', shadow=True, figsize=(8,8))
plt.title('Pie Chart for The target')
plt.show()

# %% [markdown]
# ### **Clean and Preprocess your Data** (Hint: One-Hot-Encode Categoricals)
# Another hint: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.get_dummies.html

# %%
 y_train = y_train.map({'<=50K': 0, '>50K': 1})
 y_test = y_test.map({'<=50K': 0, '>50K': 1})

# %%
X_train = pd.DataFrame(X_train.drop(["native_country"],axis=1))
X_train =  pd.DataFrame(pd.get_dummies(X_train, prefix=['workclass', 'education', 'marital_status', 'ooccupation', 'relationship','sex']))
X_train
# Out:
#        age  fnlwgt  education_num  ...  relationship_ Wife  sex_ Female  sex_ Male
# 0       39   77516             13  ...                   0            0          1
# 1       50   83311             13  ...                   0            0          1
# 2       38  215646              9  ...                   0            0          1
# 3       53  234721              7  ...                   0            0          1
# 4       28  338409             13  ...                   1            1          0
# ...    ...     ...            ...  ...                 ...          ...        ...
# 32556   27  257302             12  ...                   1            1          0
# 32557   40  154374              9  ...                   0            0          1
# 32558   58  151910              9  ...                   0            1          0
# 32559   22  201490              9  ...                   0            0          1
# 32560   52  287927              9  ...                   1            1          0
#
# [32561 rows x 61 columns]

# %%
X_test = pd.DataFrame(X_test.drop(["native_country"],axis=1))
X_test =  pd.DataFrame(pd.get_dummies(X_test, prefix=['workclass', 'education', 'marital_status', 'ooccupation', 'relationship','sex']))
X_test
# Out:
#        age  fnlwgt  education_num  ...  relationship_ Wife  sex_ Female  sex_ Male
# 0       25  226802              7  ...                   0            0          1
# 1       38   89814              9  ...                   0            0          1
# 2       28  336951             12  ...                   0            0          1
# 3       44  160323             10  ...                   0            0          1
# 4       18  103497             10  ...                   0            1          0
# ...    ...     ...            ...  ...                 ...          ...        ...
# 16276   39  215419             13  ...                   0            1          0
# 16277   64  321403              9  ...                   0            0          1
# 16278   38  374983             13  ...                   0            0          1
# 16279   44   83891             13  ...                   0            0          1
# 16280   35  182148             13  ...                   0            0          1
#
# [16281 rows x 61 columns]

# %% [markdown]
# ### **Create a kNN model**

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
pre = knn.predict(X_test)
pre
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# ### **Show us your confusion matrix and explain the results**

# %%
confusion_matrix(y_test, knn.predict(X_test))
# Out:
# array([[10948,  1487],
#        [ 2407,  1439]])

# %%
plot_confusion_matrix(knn, X=pd.DataFrame(X_test), y_true=y_test, cmap='Blues',values_format='',
                      display_labels=['<=50K', '>50K'])

# %% [markdown]
# the model predict 10948 were <=50K (true) \
# and 1439 were >50K (true) \
# the model predict 1487 were <=50k (false) \
# and 2407 were >50K (false)

# %% [markdown]
# ### **Compare to Baseline model and explain the results**

# %%
accuracy_score(y_test, pre)
# Out:
# 0.7608255021190344

# %%
0.7637737239727289 - 0.7608255021190344
# Out:
# 0.002948221853694477

# %% [markdown]
# I should not use the knn model it is less accurate than the baseline model

# %% [markdown]
# ### **BONUS ☝️**
# - Create a Logistic Regression Model
# - Compare results to kNN and Baseline and explain the results

# %% [markdown]
# ### **BONUS ✌️**
# - Use GridSearchCV with your Logistic Regression with `cv=10` passed into your grid
